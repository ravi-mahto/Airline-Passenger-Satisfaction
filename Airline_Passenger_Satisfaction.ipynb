# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
# Unnamed: 0                           103904 non-null int64
# id                                   103904 non-null int64
# Gender                               103904 non-null object
# Customer Type                        103904 non-null object
# Age                                  103904 non-null int64
# Type of Travel                       103904 non-null object
# Class                                103904 non-null object
# Flight Distance                      103904 non-null int64
# Inflight wifi service                103904 non-null int64
# Departure/Arrival time convenient    103904 non-null int64
# Ease of Online booking               103904 non-null int64
# Gate location                        103904 non-null int64
# Food and drink                       103904 non-null int64
# Online boarding                      103904 non-null int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
df.isnull().sum()[df.isnull().sum()!=0]
# Out:
# Arrival Delay in Minutes    310
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0', 'id'], inplace = True)

# %%
df.shape
# Out:
# (103904, 23)

# %%
num_col = df.select_dtypes(exclude=['object'])
num_col.columns
# Out:
# Index(['Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
cat_col = df.select_dtypes(include=['object'])
cat_col.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction'], dtype='object')

# %%
cat_col.Gender.value_counts()
# Out:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64

# %%
cat_col['Customer Type'].value_counts()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
cat_col['Type of Travel'].value_counts()
# Out:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64

# %%
cat_col.Class.value_counts()
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
cat_col.satisfaction.value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
# Encoding the Categorical Variables

# %%
df1 = df.copy()

# %%
df1['Arrival Delay in Minutes']=df1['Arrival Delay in Minutes'].replace(np.NaN, df1['Arrival Delay in Minutes'].median())

# %%
df1.isnull().sum()[df1.isnull().sum()!=0]
# Out:
# Series([], dtype: int64)

# %%
df1.head(2)
# Out:
#   Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0   Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1   Male  disloyal Customer   25  Business travel  Business              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
df1['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df1['Customer Type'].replace({'Loyal Customer':1,'disloyal Customer':0},inplace=True)

# %%
df1['Type of Travel'].replace({'Business travel':1,'Personal Travel':0},inplace=True)

# %%
df1['Class'].replace({'Business':2,'Eco Plus':1,'Eco':0},inplace=True)

# %%
df1['satisfaction'].replace({'satisfied':1,'neutral or dissatisfied':0},inplace=True)

# %%
df1.head(2)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              1   13               0      1              460
# 1       1              0   25               1      2              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# ...

# %%
df1.hist(bins=15,figsize=(15,15))
plt.show()

# %%
for i in num_col.columns:
    sns.boxplot(y=num_col[i])
    plt.show()

# %%
cat_col.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction'], dtype='object')

# %%
plt.figure(figsize=(15,15))

plt.subplot(4,2,1)
sns.countplot(x=df["Gender"], hue="satisfaction", data=df1)
plt.subplot(4,2,2)
sns.countplot(x=df["Customer Type"], hue="satisfaction", data=df1)
plt.subplot(4,2,3)
sns.countplot(x=df["Type of Travel"], hue="satisfaction", data=df1)
plt.subplot(4,2,4)
sns.countplot(x=df["Class"], hue="satisfaction", data=df1)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(x=df["satisfaction"], y="Arrival Delay in Minutes", data=df1)
plt.subplot(2,2,2)
sns.boxplot(x=df["satisfaction"], y="Departure Delay in Minutes", data=df1)
plt.subplot(2,2,3)
sns.boxplot(x=df["satisfaction"], y="Age", data=df1)
plt.subplot(2,2,4)
sns.boxplot(x=df["satisfaction"], y="Flight Distance", data=df1)
plt.show()

# %%
df1.head(2)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              1   13               0      1              460
# 1       1              0   25               1      2              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# ...

# %%
#df1.corr()['satisfaction'].sort_values(ascending = False)

# %%
plt.figure(figsize=[18,18])
ax = sns.heatmap(df1.corr(),cmap='Greens', annot =True)
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
plt.show()

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Top features in the dataset with target

# %%
x1 = df1.drop(['satisfaction'],axis=1)  #independent columns
y1 = df1['satisfaction']

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x1,y1)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x1.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(60,'Score'))  #print 10 best features
# Out:
#                                 Specs         Score
# 5                     Flight Distance  7.753602e+06
# 21           Arrival Delay in Minutes  3.383326e+04
# 20         Departure Delay in Minutes  2.613488e+04
# 4                               Class  2.290858e+04
# 11                    Online boarding  1.476196e+04
# 2                                 Age  1.134151e+04
# 13             Inflight entertainment  8.711182e+03
# 3                      Type of Travel  6.501444e+03
# 12                       Seat comfort  6.419260e+03
# 6               Inflight wifi service  5.422334e+03
# 14                   On-board service  5.299337e+03
# 15                   Leg room service  5.261977e+03
# 19                        Cleanliness  5.071376e+03
# 17                    Checkin service  2.808445e+03
# 10                     Food and drink  2.527913e+03
# 16                   Baggage handling  2.448815e+03
# 18                   Inflight service  2.362947e+03
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(x1,y1)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers

#plot graph of feature importances for better visualization
plt.figure(figsize=(12,7))
feat_importances = pd.Series(model.feature_importances_, index=x1.columns)
feat_importances.nlargest(28).plot(kind='barh')

plt.show()
# Out:
# [0.00690256 0.05260305 0.02140706 0.12283536 0.11812426 0.0235656
#  0.13384792 0.01887476 0.04215529 0.0185259  0.01363707 0.12093215
#  0.05144717 0.04681128 0.03557639 0.03268141 0.03394435 0.03038062
#  0.02553901 0.02827846 0.01079487 0.01113546]

# %% [markdown]
# ## Base model

# %%
x = df1.drop(['satisfaction'],axis=1)  #independent columns
y = df1['satisfaction']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,roc_curve,classification_report,f1_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state=3)

# %%
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# fit the predictor and target
rfc.fit(x_train, y_train)

# predict
rfc_predict = rfc.predict(x_test)
# check performance
print('ROCAUC score:',roc_auc_score(y_test, rfc_predict))
print('Accuracy score:',accuracy_score(y_test, rfc_predict))
print('F1 score:',f1_score(y_test, rfc_predict))
# Out:
# ROCAUC score: 0.9589670726891957
# Accuracy score: 0.9618247144873604
# F1 score: 0.955060422960725

# %%
# LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# fit the predictor and target
lr.fit(x_train, y_train)

# predict
lr_predict = lr.predict(x_test)
# check performance
print('ROCAUC score:',roc_auc_score(y_test, lr_predict))
print('Accuracy score:',accuracy_score(y_test, lr_predict))
print('F1 score:',f1_score(y_test, lr_predict))
# Out:
# ROCAUC score: 0.7700336603436795
# Accuracy score: 0.7687347619658668
# F1 score: 0.7446785904019833

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

# predict
knn_predict = knn.predict(x_test)

print('ROCAUC score:',roc_auc_score(y_test, knn_predict))
print('Accuracy score:',accuracy_score(y_test, knn_predict))
print('F1 score:',f1_score(y_test, knn_predict))
# Out:
# ROCAUC score: 0.7359230954796955
# Accuracy score: 0.7454767098678301
# F1 score: 0.6933127174333205

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier().fit(x_train, y_train)

# predict
xgb_predict = xgb.predict(x_test)

# accuracy score
print('ROCAUC score:',roc_auc_score(y_test, xgb_predict))
print('Accuracy score:',accuracy_score(y_test, xgb_predict))
print('F1 score:',f1_score(y_test, xgb_predict))
# Out:
# ROCAUC score: 0.959865175484461
# Accuracy score: 0.9622738354933915
# F1 score: 0.9557562076749436

# %% [markdown]
# ## Feature Engineering

# %%
df2 = df1.copy()

# %%
df2['Total_Delay'] = df2['Departure Delay in Minutes'] + df2['Arrival Delay in Minutes']

# %%
df2.shape
# Out:
# (103904, 24)

# %%
df2.drop(columns=['Gender','Gate location'], axis=1,inplace = True)

# %%
df2.shape
# Out:
# (103904, 22)

# %%
df2.head(2)
# Out:
#    Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0              1   13               0      1              460
# 1              0   25               1      2              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Food and drink  Online boarding  ...  \
# 0                       3               5                3  ...
# 1                       3               1                3  ...
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# ...

# %%
# applying StandardScaler

# %%
x = df2.drop(['satisfaction'],axis=1)  #independent columns
y = df2['satisfaction']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X=sc.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.30,random_state=3)

# %%
## Hyperparamter

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
xgb = XGBClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = xgb, param_grid = param_grid, cv = 3, n_jobs = -1 , scoring='r2' , verbose=2)

grid_search.fit(x_train , y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed: 60.0min finished
# [18:31:41] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'auto', 'n_estimators': 250}

# %%
xgb = XGBClassifier(**grid_search.best_params_)

xgb.fit(x_train, y_train)

# predict
xgb_predict = xgb.predict(x_test)

# accuracy score
print('ROCAUC score:',roc_auc_score(y_test, xgb_predict))
print('Accuracy score:',accuracy_score(y_test, xgb_predict))
print('F1 score:',f1_score(y_test, xgb_predict))
# Out:
# [18:32:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { max_features } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ROCAUC score: 0.9584235201248953
# Accuracy score: 0.9606377518285641
# F1 score: 0.9539258758589614
